# %%
import pandas as pd

# %%
dataset=pd.read_csv('Complaints.csv' , chunksize=100000)

# %%
for chunk in dataset:
    display(chunk.head())
    break
# Out:
# C:\Users\komal\AppData\Local\Temp\ipykernel_18064\47428305.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in dataset:
#   Date received                                            Product  \
# 0    2024-01-24  Credit reporting or other personal consumer re...
# 1    2024-02-26  Credit reporting or other personal consumer re...
# 2    2024-01-26  Credit reporting or other personal consumer re...
# 3    2024-05-02                                        Credit card
# 4    2024-01-26  Credit reporting or other personal consumer re...
#
#          Sub-product                                 Issue  \
# 0   Credit reporting  Incorrect information on your report
# 1   Credit reporting  Incorrect information on your report
# 2   Credit reporting  Incorrect information on your report
# 3  Store credit card                      Fees or interest
# 4   Credit reporting           Improper use of your report
#
# ...

# %%
for chunk in dataset:
    display(chunk.columns)
    break
# Out:
# C:\Users\komal\AppData\Local\Temp\ipykernel_18064\592539654.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in dataset:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
chunk
# Out:
#        Date received                                            Product  \
# 900000    2022-09-13  Credit reporting, credit repair services, or o...
# 900001    2023-03-07  Credit reporting, credit repair services, or o...
# 900002    2023-02-15  Credit reporting, credit repair services, or o...
# 900003    2023-02-15  Credit reporting, credit repair services, or o...
# 900004    2023-10-26  Credit reporting or other personal consumer re...
# ...              ...                                                ...
# 999995    2023-07-11  Credit reporting, credit repair services, or o...
# 999996    2023-03-09  Credit reporting, credit repair services, or o...
# 999997    2023-10-26  Credit reporting or other personal consumer re...
# 999998    2023-05-03  Credit reporting, credit repair services, or o...
# 999999    2023-02-18  Credit reporting, credit repair services, or o...
#
#              Sub-product                                              Issue  \
# ...

# %%
chunk.isnull().sum()
# Out:
# Date received                       0
# Product                             0
# Sub-product                        37
# Issue                               0
# Sub-issue                        6050
# Consumer complaint narrative    56952
# Company public response         39782
# Company                             0
# State                             234
# ZIP code                           20
# Tags                            92526
# Consumer consent provided?       3696
# Submitted via                       0
# Date sent to company                0
# Company response to consumer        0
# Timely response?                    0
# Consumer disputed?              97070
# Complaint ID                        0
# dtype: int64

# %%
chunk['Consumer complaint narrative']
# Out:
# 900000                                                  NaN
# 900001                                                  NaN
# 900002    Hi I am submitting this XXXX XXXX this isn't a...
# 900003    In accordance with the Fair Credit Reporting a...
# 900004                                                  NaN
#                                 ...
# 999995    In accordance with the Fair Credit Reporting a...
# 999996    Again, I was a victim of identity theft and th...
# 999997    In accordance with the Fair Credit Reporting a...
# 999998                                                  NaN
# 999999    XXXX applied for a new auto loan after her veh...
# Name: Consumer complaint narrative, Length: 100000, dtype: object

# %% [markdown]
# QUESTION 3:

# %%
nums=[10,3]

# %%
class solution:
    def largestnumber(self, nums: list[int]) -> str:
        def compare(x,y):
            a= x*10**len(str(y))+y
            b= y*10**len(str(x))+x
            print(a,b)
            return a-b
        
        import functools
        data_list= sorted(nums, key=cmp_to_key(compare), reversre = True)
        result = " "
        for i in data_list:
            result += str(i)
        return result

# %% [markdown]
# QUESTION 2:

# %%
Longest_subsequence=[2,2,2,2,2]

# %%
current_subsequence=[]
for i in range (0, len(longest_subsequence)):
    if i ==0 or longest_subsequence[i] > longest_subsequence[i-1]:
        current_subsequence.append(longest_subsequence[i])
        
        
print(current_subsequence)
print(len(current_subsequence))
# Out:
# [2]
# 1

# %%
# Out:
# 1
